# %%
import pandas as pd
import numpy as np


pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("Lead_value_Prestige.csv")
print(df.shape)
df = df.drop("Prestige Account Name", axis =1)
print(df.shape)
# Out:
# (14442, 25)
# (14442, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14442 entries, 0 to 14441
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Net Revenue       14442 non-null  float64
#  1   LEAD_STATUS       14442 non-null  int64
#  2   RGN_NAME          14442 non-null  float64
#  3   MKT_UNIT          14442 non-null  float64
#  4   LOC_NAME          14442 non-null  float64
#  5   DIV_NAME          14442 non-null  float64
#  6   NUM_UNITS         14442 non-null  int64
#  7   BU_NAME           14442 non-null  float64
#  8   RATING            14442 non-null  float64
#  9   FF_YRS_IN_BUS_CD  14442 non-null  float64
#  10  PRE_OPEN          14442 non-null  int64
#  11  CHAIN             14442 non-null  int64
#  12  CITY_CE           14442 non-null  float64
#  13  COUNTY_CE         14442 non-null  float64
#  14  STATE_CE          14442 non-null  float64
#  15  ZIP_CE            14442 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['Net Revenue', 'LEAD_STATUS', 'RGN_NAME', 'MKT_UNIT', 'LOC_NAME',
#        'DIV_NAME', 'NUM_UNITS', 'BU_NAME', 'RATING', 'FF_YRS_IN_BUS_CD',
#        'PRE_OPEN', 'CHAIN', 'CITY_CE', 'COUNTY_CE', 'STATE_CE', 'ZIP_CE',
#        'LATITUDE', 'LONGITUDE', 'FOUNTAIN_FLAG', 'Prestige account', 'CITY',
#        'COUNTY', 'STATE', 'ZIP'],
#       dtype='object')

# %%
df.head()
# Out:
#    Net Revenue  LEAD_STATUS     RGN_NAME     MKT_UNIT     LOC_NAME  \
# 0       759.60            0  7461.945589  6136.680430  6648.993659
# 1      1406.80            0  5409.862755  7302.851048  6454.455976
# 2      2088.30            0  5544.127360  4740.666806  6019.390684
# 3     12939.51            0  6798.068421  6430.993640  5923.061235
# 4      6362.95            0  5409.862755  4029.324651  5717.053843
#
#       DIV_NAME  NUM_UNITS      BU_NAME  RATING  FF_YRS_IN_BUS_CD  PRE_OPEN  \
# 0  5998.469353          1  6556.890311     0.0       6102.208892         0
# 1  5998.469353          1  6344.897185     0.0       6102.208892         0
# 2  5214.338214          1  6518.161306     1.0       6102.208892         0
# 3  5998.469353          1  6556.890311     0.0       6102.208892         0
# 4  5998.469353          6  6556.890311     0.0       6102.208892         0
#
#    CHAIN      CITY_CE    COUNTY_CE     STATE_CE       ZIP_CE   LATITUDE  \
# ...
